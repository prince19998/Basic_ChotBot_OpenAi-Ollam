# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")


## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# Data Ingestion--from the websit we need to scrape the data

from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader=WebBaseLoader("https://www.geeksforgeeks.org/ollama-explained-transforming-ai-accessibility-and-language-processing/")

# %%
loader

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/ollama-explained-transforming-ai-accessibility-and-language-processing/', 'title': 'Ollama Explained: Transforming AI Accessibility and Language Processing - GeeksforGeeks', 'description': 'A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.', 'language': 'en-US'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOllama Explained: Transforming AI Accessibility and Language Processing - GeeksforGeeks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\nCoursesDSA to DevelopmentNewly Launched!Android with KotlinGenerative AI & ChatGPTMaster Django FrameworkBecome AWS CertifiedFor Working ProfessionalsInterview 101: DSA & System DesignData Science Trai
# ...

# %%
## Load Data--> Docs --> Divide our Documnets into chunks documents----> text--> vectors---->vectors Embedding ---> vectors Store DB

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=500)
documents=text_splitter.split_documents(docs)

# %%
documents
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/ollama-explained-transforming-ai-accessibility-and-language-processing/', 'title': 'Ollama Explained: Transforming AI Accessibility and Language Processing - GeeksforGeeks', 'description': 'A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.', 'language': 'en-US'}, page_content='Ollama Explained: Transforming AI Accessibility and Language Processing - GeeksforGeeks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content'),
# ...

# %%
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings()

# %%
from langchain_community.vectorstores import FAISS
vectorstoredb=FAISS.from_documents(documents,embeddings)
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File f:\udemy krish naik Generative AI\GEN AI Env\LangChain\1-Langchain\LC_venv\Lib\site-packages\httpx\_transports\default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File f:\udemy krish naik Generative AI\GEN AI Env\LangChain\1-Langchain\LC_venv\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File f:\udemy krish naik Generative AI\GEN AI Env\LangChain\1-Langchain\LC_venv\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
# ...

# %%
vectorstoredb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 vectorstoredb
#
# NameError: name 'vectorstoredb' is not defined

# %%
## Query From a vector db
query="LangSmith has two usage limits: total traces and extended"
result=vectorstoredb.similarity_search(query)
result[0].page_content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 ## Query From a vector db
#       2 query="LangSmith has two usage limits: total traces and extended"
# ----> 3 result=vectorstoredb.similarity_search(query)
#       4 result[0].page_content
#
# NameError: name 'vectorstoredb' is not defined

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")

# %%
## Retrieval Chain, Document chain

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
    """
Answer the following question based only on the provided context:
<context>
{context}
</context>


"""
)

document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 17
#       4 from langchain_core.prompts import ChatPromptTemplate
#       6 prompt=ChatPromptTemplate.from_template(
#       7     """
#       8 Answer the following question based only on the provided context:
#    (...)
#      14 """
#      15 )
# ---> 17 document_chain=create_stuff_documents_chain(llm,prompt)
#      18 document_chain
#
# NameError: name 'llm' is not defined

# %%
from langchain_core.documents import Document
document_chain.invoke({
    "input":"LangSmith has two usage limits: total traces and extended",
    "context":[Document(page_content="LangSmith has two usage limits: total traces and extended traces. These correspond to the two metrics we've been tracking on our usage graph. ")]
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 from langchain_core.documents import Document
# ----> 2 document_chain.invoke({
#       3     "input":"LangSmith has two usage limits: total traces and extended",
#       4     "context":[Document(page_content="LangSmith has two usage limits: total traces and extended traces. These correspond to the two metrics we've been tracking on our usage graph. ")]
#       5 })
#
# NameError: name 'document_chain' is not defined

# %%
### Input--->Retriever--->vectorstoredb

vectorstoredb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 ### Input--->Retriever--->vectorstoredb
# ----> 3 vectorstoredb
#
# NameError: name 'vectorstoredb' is not defined

# %%
retriever=vectorstoredb.as_retriever()
from langchain.chains import create_retrieval_chain
retrieval_chain=create_retrieval_chain(retriever,document_chain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 retriever=vectorstoredb.as_retriever()
#       2 from langchain.chains import create_retrieval_chain
#       3 retrieval_chain=create_retrieval_chain(retriever,document_chain)
#
# NameError: name 'vectorstoredb' is not defined

# %%
retrieval_chain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 retrieval_chain
#
# NameError: name 'retrieval_chain' is not defined

# %%
## Get the response form the LLM
response=retrieval_chain.invoke({"input":"LangSmith has two usage limits: total traces and extended"})
response['answer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ## Get the response form the LLM
# ----> 2 response=retrieval_chain.invoke({"input":"LangSmith has two usage limits: total traces and extended"})
#       3 response['answer']
#
# NameError: name 'retrieval_chain' is not defined

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
response['context']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response['context']
#
# NameError: name 'response' is not defined
